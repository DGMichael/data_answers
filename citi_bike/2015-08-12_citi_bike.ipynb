# %%
import requests

# %%
r = requests.get('http://www.citibikenyc.com/stations/json')

# %%
type(r)
# Out:
# requests.models.Response

# %%
dir(r)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__getstate__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__module__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
r.text
# Out:
# u'{"executionTime":"2015-08-17 10:46:42 PM","stationBeanList":[{"id":72,"stationName":"W 52 St & 11 Ave","availableDocks":5,"totalDocks":39,"latitude":40.76727216,"longitude":-73.99392888,"statusValue":"In Service","statusKey":1,"availableBikes":33,"stAddress1":"W 52 St & 11 Ave","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":"2015-08-17 10:43:47 PM","landMark":""},{"id":79,"stationName":"Franklin St & W Broadway","availableDocks":21,"totalDocks":33,"latitude":40.71911552,"longitude":-74.00666661,"statusValue":"In Service","statusKey":1,"availableBikes":9,"stAddress1":"Franklin St & W Broadway","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":"2015-08-17 10:45:54 PM","landMark":""},{"id":82,"stationName":"St James Pl & Pearl St","availableDocks":15,"totalDocks":27,"latitude":40.71117416,"longitude":-74.00016545,"statusValue":"In Service","statusKey":1,"a
# ...

# %%
r.json()
# Out:
# {u'executionTime': u'2015-08-17 10:46:42 PM',
#  u'stationBeanList': [{u'altitude': u'',
#    u'availableBikes': 33,
#    u'availableDocks': 5,
#    u'city': u'',
#    u'id': 72,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-08-17 10:43:47 PM',
#    u'latitude': 40.76727216,
#    u'location': u'',
#    u'longitude': -73.99392888,
#    u'postalCode': u'',
#    u'stAddress1': u'W 52 St & 11 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 52 St & 11 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 9,
#    u'availableDocks': 21,
#    u'city': u'',
#    u'id': 79,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-08-17 10:45:54 PM',
#    u'latitude': 40.71911552,
#    u'location': u'',
#    u'longitude': -74.00666661,
#    u'postalCode': u'',
#    u'stAddress1': u'Franklin St & W Broadway',
#    u'stAddress2': u'',
# ...

# %%
r.json().keys()
# Out:
# [u'executionTime', u'stationBeanList']

# %%
r.json()['executionTime']
# Out:
# u'2015-08-17 10:46:42 PM'

# %%
r.json()['stationBeanList']
# Out:
# [{u'altitude': u'',
#   u'availableBikes': 33,
#   u'availableDocks': 5,
#   u'city': u'',
#   u'id': 72,
#   u'landMark': u'',
#   u'lastCommunicationTime': u'2015-08-17 10:43:47 PM',
#   u'latitude': 40.76727216,
#   u'location': u'',
#   u'longitude': -73.99392888,
#   u'postalCode': u'',
#   u'stAddress1': u'W 52 St & 11 Ave',
#   u'stAddress2': u'',
#   u'stationName': u'W 52 St & 11 Ave',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
#   u'testStation': False,
#   u'totalDocks': 39},
#  {u'altitude': u'',
#   u'availableBikes': 9,
#   u'availableDocks': 21,
#   u'city': u'',
#   u'id': 79,
#   u'landMark': u'',
#   u'lastCommunicationTime': u'2015-08-17 10:45:54 PM',
#   u'latitude': 40.71911552,
#   u'location': u'',
#   u'longitude': -74.00666661,
#   u'postalCode': u'',
#   u'stAddress1': u'Franklin St & W Broadway',
#   u'stAddress2': u'',
#   u'stationName': u'Franklin St & W Broadway',
#   u'statusKey': 1,
#   u'statusValue': u'In Service',
# ...

# %%
key_list = []
for station in r.json()["stationBeanList"]:
    for k in station.keys():
        if k not in key_list:
            key_list.append(k)

# %%
key_list
# Out:
# [u'availableDocks',
#  u'totalDocks',
#  u'city',
#  u'altitude',
#  u'stAddress2',
#  u'longitude',
#  u'lastCommunicationTime',
#  u'postalCode',
#  u'statusValue',
#  u'testStation',
#  u'stAddress1',
#  u'stationName',
#  u'landMark',
#  u'latitude',
#  u'statusKey',
#  u'availableBikes',
#  u'id',
#  u'location']

# %%
r.json()['stationBeanList'][0]
# Out:
# {u'altitude': u'',
#  u'availableBikes': 33,
#  u'availableDocks': 5,
#  u'city': u'',
#  u'id': 72,
#  u'landMark': u'',
#  u'lastCommunicationTime': u'2015-08-17 10:43:47 PM',
#  u'latitude': 40.76727216,
#  u'location': u'',
#  u'longitude': -73.99392888,
#  u'postalCode': u'',
#  u'stAddress1': u'W 52 St & 11 Ave',
#  u'stAddress2': u'',
#  u'stationName': u'W 52 St & 11 Ave',
#  u'statusKey': 1,
#  u'statusValue': u'In Service',
#  u'testStation': False,
#  u'totalDocks': 39}

# %%
len(r.json()['stationBeanList'])
# Out:
# 508

# %%
from pandas.io.json import json_normalize
df = json_normalize(r.json()['stationBeanList'])

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

df.head()
# Out:
#   altitude  availableBikes  availableDocks city   id landMark  \
# 0                       33               5        72
# 1                        9              21        79
# 2                        9              15        82
# 3                       51              10        83
# 4                        6              30       116
#
#     lastCommunicationTime   latitude location  longitude postalCode  \
# 0  2015-08-17 10:43:47 PM  40.767272          -73.993929
# 1  2015-08-17 10:45:54 PM  40.719116          -74.006667
# 2  2015-08-17 10:42:55 PM  40.711174          -74.000165
# 3  2015-08-17 10:43:28 PM  40.683826          -73.976323
# 4  2015-08-17 10:46:29 PM  40.741776          -74.001497
#
#                       stAddress1 stAddress2                    stationName  \
# 0               W 52 St & 11 Ave                          W 52 St & 11 Ave
# 1       Franklin St & W Broadway                  Franklin St & W Broadway
# ...

# %%
df['availableBikes'].hist()

# %%
df["totalDocks"].hist()

# %%
df['testStation']
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# ...
# 493    False
# 494    False
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# 500    False
# 501    False
# 502    False
# 503    False
# 504    False
# 505    False
# 506    False
# 507    False
# Name: testStation, Length: 508, dtype: bool

# %%
df["totalDocks"].mean()
# Out:
# 24.187007874015748

# %%
df["totalDocks"].sum()
# Out:
# 12287

# %%
df.head()
# Out:
#   altitude  availableBikes  availableDocks city   id landMark  \
# 0                       33               5        72
# 1                        9              21        79
# 2                        9              15        82
# 3                       51              10        83
# 4                        6              30       116
#
#     lastCommunicationTime   latitude location  longitude postalCode  \
# 0  2015-08-17 10:43:47 PM  40.767272          -73.993929
# 1  2015-08-17 10:45:54 PM  40.719116          -74.006667
# 2  2015-08-17 10:42:55 PM  40.711174          -74.000165
# 3  2015-08-17 10:43:28 PM  40.683826          -73.976323
# 4  2015-08-17 10:46:29 PM  40.741776          -74.001497
#
#                       stAddress1 stAddress2                    stationName  \
# 0               W 52 St & 11 Ave                          W 52 St & 11 Ave
# 1       Franklin St & W Broadway                  Franklin St & W Broadway
# ...

# %%
condition = (df['statusValue'] == "In Service") #Generate a boolean mask of true/false for each row
df[condition]['totalDocks'].mean() #Apply the boolean mask and take the mean of all rows which equate to True
# Out:
# 34.460227272727273

# %%
condition #Exposes the boolean array (mask)
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# ...
# 493    False
# 494    False
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# 500    False
# 501    False
# 502    False
# 503    False
# 504    False
# 505    False
# 506    False
# 507    False
# Name: statusValue, Length: 508, dtype: bool

# %%
df[condition]['totalDocks'] #Demonstrates the masking of features by the boolean condition.
# Out:
# 0     39
# 1     33
# 2     27
# 3     62
# 4     39
# 5     19
# 6     19
# 7     31
# 8     30
# 9     46
# 10    24
# 11    19
# 12    39
# 13    33
# 14    31
# ...
# 408    27
# 409    30
# 410    32
# 411    20
# 412    27
# 413    26
# 414    27
# 415    23
# 416    34
# 417    35
# 419    31
# 420    31
# 470    31
# 471    21
# 472    42
# Name: totalDocks, Length: 352, dtype: int64

# %%
df['totalDocks'][condition] #The same thing no matter what the order.
# Out:
# 0     39
# 1     33
# 2     27
# 3     62
# 4     39
# 5     19
# 6     19
# 7     31
# 8     30
# 9     46
# 10    24
# 11    19
# 12    39
# 13    33
# 14    31
# ...
# 408    27
# 409    30
# 410    32
# 411    20
# 412    27
# 413    26
# 414    27
# 415    23
# 416    34
# 417    35
# 419    31
# 420    31
# 470    31
# 471    21
# 472    42
# Name: totalDocks, Length: 352, dtype: int64

# %%
#Create a SQL table:
import sqlite3 as lite
con = lite.connect("citi_bike.db")
cur = con.cursor()

with con: #Called a 'context manager'. Will execute the create table block at end of next statement.
    cur.execute('CREATE TABLE citibike_reference (id INT PRIMARY KEY, totalDocks INT, city TEXT, altitude INT, stAddress2 TEXT, longitude NUMERIC, postalCode TEXT, testStation TEXT, stAddress1 TEXT, stationName TEXT, landMark TEXT, latitude NUMERIC, location TEXT )')

# %% [raw]
# #This is the SQL table CREATE statement from above:
# CREATE TABLE citibike_reference ( #Create a table called citibike_reference
#     id INT PRIMARY KEY, #Uniquely identifies the record
#     totalDocks INT, #totaldocks as an int
#     city TEXT, #city as a text
#     altitude INT, ...
#     stAddress2 TEXT, ...
#     longitude NUMERIC, ...
#     postalCode TEXT, ...
#     testStation TEXT, ...
#     stAddress1 TEXT, ...
#     stationName TEXT, ...
#     landMark TEXT, ...
#     latitude NUMERIC, ...
#     location TEXT ....
# )
#
# #a prepared SQL statement we're going to execute over and over again
# sql = "INSERT INTO citibike_reference (id, totalDocks, city, altitude, stAddress2, longitude, postalCode, testStation, stAddress1, stationName, landMark, latitude, location) VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?)"
#
# ^This is a parameterized SQL query.  '?' chars will be replaced with values.  A lot like the python format function.
#
# #for loop to populate values in the database
# with con:
#     for station in r.json()['stationBeanList']:
#         #id, totalDocks, city, altitude, stAddress2, longitude, postalCode, testStation, stAddress1, stationName, landMark, latitude, location)
#         cur.execute(sql,(station['id'],station['totalDocks'],station['city'],station['altitude'],station['stAddress2'],station['longitude'],station['postalCode'],station['testStation'],station['stAddress1'],station['stationName'],station['landMark'],station['latitude'],station['location']))

# %%
#Prepared sql statement for injection below:
sql = "INSERT INTO citibike_reference (id, totalDocks, city, altitude, stAddress2, longitude, postalCode, testStation, stAddress1, stationName, landMark, latitude, location) VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?)"

#for loop to populate values in the database
with con:
    for station in r.json()['stationBeanList']:
        #id, totalDocks, city, altitude, stAddress2, longitude, postalCode, testStation, stAddress1, stationName, landMark, latitude, location)
        cur.execute(sql,(station['id'],station['totalDocks'],station['city'],station['altitude'],station['stAddress2'],station['longitude'],station['postalCode'],station['testStation'],station['stAddress1'],station['stationName'],station['landMark'],station['latitude'],station['location']))

# %%
station_ids = df['id'].tolist() #Extract column and send to list.

# %%
station_ids[0:5]
# Out:
# [72, 79, 82, 83, 116]

# %%
#add the '_' to the station name and also add the data type for SQLite
station_ids = ['_' + str(x) + ' INT' for x in station_ids]

# %%
station_ids[0:5]
# Out:
# ['_72 INT', '_79 INT', '_82 INT', '_83 INT', '_116 INT']

# %%
#create the table
#in this case, we're concatentating the string and joining all the station ids
#(now with '_' and 'INT' added)

with con:
    cur.execute("CREATE TABLE available_bikes ( execution_time INT, " +  ", ".join(station_ids) + ");")

# %%
# a package with datetime objects
import time

# a package for parsing a string into a Python datetime object
from dateutil.parser import parse 

import collections


#take the string and parse it into a Python datetime object
exec_time = parse(r.json()['executionTime'])

# %%
exec_time
# Out:
# datetime.datetime(2015, 8, 17, 22, 46, 42)

# %%
with con:
    cur.execute('INSERT INTO available_bikes (execution_time) VALUES (?)', (exec_time.strftime('%s'),))

# %%
id_bikes = collections.defaultdict(int) #defaultdict to store available bikes by station

#loop through the stations in the station list
for station in r.json()['stationBeanList']:
    id_bikes[station['id']] = station['availableBikes']

#iterate through the defaultdict to update the values in the database
with con:
    for k, v in id_bikes.iteritems():
        cur.execute("UPDATE available_bikes SET _" + str(k) + " = " + str(v) + " WHERE execution_time = " + exec_time.strftime('%s') + ";")
