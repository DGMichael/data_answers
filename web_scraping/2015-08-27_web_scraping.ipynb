# %%
from bs4 import BeautifulSoup
import requests

url = 'http://web.archive.org/web/20110514112442/http://unstats.un.org/unsd/demographic/products/socind/education.htm'
r = requests.get(url)

# %%
soup = BeautifulSoup(r.content)
# Out:
# /Library/Python/2.7/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html.parser")
#
#   markup_type=markup_type))

# %%
soup
# Out:
# <html><!-- #BeginTemplate "/Templates/demogsocial2.dwt" --><!-- DW6 -->\n<head>\n<script src="/static/js/analytics.js" type="text/javascript"></script>\n<script type="text/javascript">archive_analytics.values.server_name="wwwb-app19.us.archive.org";archive_analytics.values.server_ms=263;</script>\n<link href="/static/css/banner-styles.css" rel="stylesheet" type="text/css"/>\n<meta content="text/html; charset=unicode-escape" http-equiv="Content-Type">\n<title>United Nations Statistics Division - Demographic and Social Statistics</title>\n<style type="text/css">\r\n<!--\r\n.style8 {font-size:10px; background-color:#fff; font-family: verdana, geneva, san-serif;}\r\n-->\r\n</style>\n<link href="/web/20110514112442cs_/http://unstats.un.org/unsd/unsd2.css" rel="stylesheet" type="text/css"/>\n<link href="/web/20110514112442cs_/http://unstats.un.org/unsd/unsd.css" rel="stylesheet" type="text/css"/><script language="javascript" src="/web/20110514112442js_/http://www.un.org/search/formValidate
# ...

# %%
for row in soup('table'):
    print row
# Out:
# <table style="width:100%;"><tbody><tr>
# <td id="wm-logo">
# <a href="/web/" title="Wayback Machine home page"><img alt="Wayback Machine" border="0" height="39" src="/static/images/toolbar/wayback-toolbar-logo.png" width="110"/></a>
# </td>
# <td class="c">
# <table style="margin:0 auto;"><tbody><tr>
# <td class="u" colspan="2">
# <form action="/web/form-submit.jsp" id="wmtb" method="get" name="wmtb" target="_top"><input id="wmtbURL" name="url" onfocus="this.focus();this.select();" style="width:400px;" type="text" value="http://unstats.un.org/unsd/demographic/products/socind/education.htm"/><input name="type" type="hidden" value="replay"/><input name="date" type="hidden" value="20110514112442"/><input type="submit" value="Go"/><span id="wm_tb_options" style="display:block;"></span></form>
# </td>
# <td class="n" rowspan="2">
# <table><tbody>
# <!-- NEXT/PREV MONTH NAV AND MONTH INDICATOR -->
# <tr class="m">
# <td class="b" nowrap="nowrap">
# ...

# %%
dir(soup)
# Out:
# ['ASCII_SPACES',
#  'DEFAULT_BUILDER_FEATURES',
#  'HTML_FORMATTERS',
#  'NO_PARSER_SPECIFIED_WARNING',
#  'ROOT_TAG_NAME',
#  'XML_FORMATTERS',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__len__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_attr_value_as_string',
#  '_attribute_checker',
#  '_feed',
#  '_find_all',
#  '_find_one',
#  '_formatter_for_name',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_most_recent_element',
#  '_popToTag',
#  '_select_debug',
#  '_selector_combinators',
# ...

# %% [markdown]
# #Initial Attempt
# It looks like <tr class="tcont"> is the line before each data entry....
# Then the entry will end with </tr>
# So a rough algorithm:
# for line in object:
# check if the line matches the first line of a data element:
# if yes, start counting:
# line1 = Country name, split by >COUNTRY<
# line2 = year
# line3 = junk
# line4 = junk
# line5 = total_value
# line6 = junk
# line7 = junk
# line8 = Men
# line9 = junk
# line10 = junk
# line11 = Women

# %%
#This doesn't work
def parse_soup(soup_obj):
    for line in soup_obj:
        if line == '<tr class="tcont">':
            print line
            print "Found one"

# %%
#This doesn't work
for line in soup("table"):
    if line == '<tr class="tcont">':
        print "Found one"

# %%
type(soup("table"))
# Out:
# bs4.element.ResultSet

# %%
soup.head
# Out:
# <head>\n<script src="/static/js/analytics.js" type="text/javascript"></script>\n<script type="text/javascript">archive_analytics.values.server_name="wwwb-app19.us.archive.org";archive_analytics.values.server_ms=263;</script>\n<link href="/static/css/banner-styles.css" rel="stylesheet" type="text/css"/>\n<meta content="text/html; charset=unicode-escape" http-equiv="Content-Type">\n<title>United Nations Statistics Division - Demographic and Social Statistics</title>\n<style type="text/css">\r\n<!--\r\n.style8 {font-size:10px; background-color:#fff; font-family: verdana, geneva, san-serif;}\r\n-->\r\n</style>\n<link href="/web/20110514112442cs_/http://unstats.un.org/unsd/unsd2.css" rel="stylesheet" type="text/css"/>\n<link href="/web/20110514112442cs_/http://unstats.un.org/unsd/unsd.css" rel="stylesheet" type="text/css"/><script language="javascript" src="/web/20110514112442js_/http://www.un.org/search/formValidate.js"></script>\n<script language="javascript" src="/web/20110514112442js_
# ...

# %%
soup.title
# Out:
# <title>United Nations Statistics Division - Demographic and Social Statistics</title>

# %%
soup.body.b

# %%
soup.a
# Out:
# <a href="/web/" title="Wayback Machine home page"><img alt="Wayback Machine" border="0" height="39" src="/static/images/toolbar/wayback-toolbar-logo.png" width="110"/></a>

# %%
len(soup.contents)
# Out:
# 8

# %%
soup.find_all('tr')
# Out:
# [<tr>\n<td id="wm-logo">\n<a href="/web/" title="Wayback Machine home page"><img alt="Wayback Machine" border="0" height="39" src="/static/images/toolbar/wayback-toolbar-logo.png" width="110"/></a>\n</td>\n<td class="c">\n<table style="margin:0 auto;"><tbody><tr>\n<td class="u" colspan="2">\n<form action="/web/form-submit.jsp" id="wmtb" method="get" name="wmtb" target="_top"><input id="wmtbURL" name="url" onfocus="this.focus();this.select();" style="width:400px;" type="text" value="http://unstats.un.org/unsd/demographic/products/socind/education.htm"/><input name="type" type="hidden" value="replay"/><input name="date" type="hidden" value="20110514112442"/><input type="submit" value="Go"/><span id="wm_tb_options" style="display:block;"></span></form>\n</td>\n<td class="n" rowspan="2">\n<table><tbody>\n<!-- NEXT/PREV MONTH NAV AND MONTH INDICATOR -->\n<tr class="m">\n<td class="b" nowrap="nowrap">\n<a href="/web/20100819143645/http://unstats.un.org/unsd/demographic/products/socind/educ
# ...

# %%
list1= soup.find_all('tr')

# %%
len(list1)
# Out:
# 212

# %%
for element in list1:
    print element
# Out:
# <tr>
# <td id="wm-logo">
# <a href="/web/" title="Wayback Machine home page"><img alt="Wayback Machine" border="0" height="39" src="/static/images/toolbar/wayback-toolbar-logo.png" width="110"/></a>
# </td>
# <td class="c">
# <table style="margin:0 auto;"><tbody><tr>
# <td class="u" colspan="2">
# <form action="/web/form-submit.jsp" id="wmtb" method="get" name="wmtb" target="_top"><input id="wmtbURL" name="url" onfocus="this.focus();this.select();" style="width:400px;" type="text" value="http://unstats.un.org/unsd/demographic/products/socind/education.htm"/><input name="type" type="hidden" value="replay"/><input name="date" type="hidden" value="20110514112442"/><input type="submit" value="Go"/><span id="wm_tb_options" style="display:block;"></span></form>
# </td>
# <td class="n" rowspan="2">
# <table><tbody>
# <!-- NEXT/PREV MONTH NAV AND MONTH INDICATOR -->
# <tr class="m">
# <td class="b" nowrap="nowrap">
# ...

# %%
list2 = soup.find("tr")

# %%
len(list2)
# Out:
# 7

# %%
list2
# Out:
# <tr>\n<td id="wm-logo">\n<a href="/web/" title="Wayback Machine home page"><img alt="Wayback Machine" border="0" height="39" src="/static/images/toolbar/wayback-toolbar-logo.png" width="110"/></a>\n</td>\n<td class="c">\n<table style="margin:0 auto;"><tbody><tr>\n<td class="u" colspan="2">\n<form action="/web/form-submit.jsp" id="wmtb" method="get" name="wmtb" target="_top"><input id="wmtbURL" name="url" onfocus="this.focus();this.select();" style="width:400px;" type="text" value="http://unstats.un.org/unsd/demographic/products/socind/education.htm"/><input name="type" type="hidden" value="replay"/><input name="date" type="hidden" value="20110514112442"/><input type="submit" value="Go"/><span id="wm_tb_options" style="display:block;"></span></form>\n</td>\n<td class="n" rowspan="2">\n<table><tbody>\n<!-- NEXT/PREV MONTH NAV AND MONTH INDICATOR -->\n<tr class="m">\n<td class="b" nowrap="nowrap">\n<a href="/web/20100819143645/http://unstats.un.org/unsd/demographic/products/socind/educa
# ...

# %%
soup('table')[6]
# Out:
# <table border="0" cellpadding="0" cellspacing="0" width="800">\n<tr valign="top">\n<td><!-- #BeginEditable "MainContent" -->\n<table align="center" border="0" width="540">\n<tr>\n<td cllcontsubhd"="" colspan="2" valign="bottom"><h2 align="center"><a name="Top"></a>Social \r\n              indicators </h2></td>\n</tr>\n<tr>\n<td cllcontsubhd"="" colspan="2" height="23" valign="top"><div align="center" class="csubhd"><a href="default.htm">Introduction</a> \r\n              | <a href="statistics.htm">Statistics</a></div></td>\n</tr>\n</table>\n<table cellpadding="0" cellspacing="0">\n<tr>\n<td height="1" width="797"><div align="right">\n<p class="Clear"><a href="Education_Dec2010.xls" style="color: #666; font-weight: bold">Download data</a> <a href="Education_Dec2010.xls"><img alt="Excel" border="0" height="21" name="Excel" src="/web/20110514112442im_/http://unstats.un.org/unsd/img/excel.gif" width="22"/></a></p>\n<div align="left">\n<table align="left" cellpadding="0" cellspacing="0">\
# ...

# %%
soup('table')[6].find("tr")
# Out:
# <tr valign="top">\n<td><!-- #BeginEditable "MainContent" -->\n<table align="center" border="0" width="540">\n<tr>\n<td cllcontsubhd"="" colspan="2" valign="bottom"><h2 align="center"><a name="Top"></a>Social \r\n              indicators </h2></td>\n</tr>\n<tr>\n<td cllcontsubhd"="" colspan="2" height="23" valign="top"><div align="center" class="csubhd"><a href="default.htm">Introduction</a> \r\n              | <a href="statistics.htm">Statistics</a></div></td>\n</tr>\n</table>\n<table cellpadding="0" cellspacing="0">\n<tr>\n<td height="1" width="797"><div align="right">\n<p class="Clear"><a href="Education_Dec2010.xls" style="color: #666; font-weight: bold">Download data</a> <a href="Education_Dec2010.xls"><img alt="Excel" border="0" height="21" name="Excel" src="/web/20110514112442im_/http://unstats.un.org/unsd/img/excel.gif" width="22"/></a></p>\n<div align="left">\n<table align="left" cellpadding="0" cellspacing="0">\n<tr class="bar1">\n<td colspan="12" height="30"><span style="fo
# ...
